# %% [markdown]
# ## Question 1
#
# Matplotlib is a data visualization library that is used in available in python. Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Uses:
# 1. Creating static and interactive visualizations.
# 2. Makes Complicated data trend or relationship easier with its visualizing techniques.
# 3. Its an addition to data analysis to give better understanding of the data to the stakeholders.
#
# Five plots that can be plotted using the Pyplot module:
# 1. Bar Plot
# 2. Histogram
# 3. Line graph
# 4. Scatter Diagram
# 5. Pie Chart

# %% [markdown]
# ## Question 2
#
# Scatter plot's primary uses are to observe and show relationships between two numeric variables.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0,2,50)
y = 3 + np.random.normal(0,2,len(x))
plt.scatter(x,y)
plt.title("Scatter diagram")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %% [markdown]
# ## Question 3
#
# The subplot function in Matplotlib is used to create a grid of subplots within a single figure. It allows you to display multiple plots in a single figure, making it easier to compare different visualizations or analyze data from various perspectives.

# %%
import numpy as np
import matplotlib.pyplot as plt
x1 = np.array([0,1,2,3,4,5])
y1 = np.array([0,100,200,300,400,500])
x2 = np.array([0,1,2,3,4,5])
y2 = np.array([50,20,40,20,60,70])
x3 = np.array([0,1,2,3,4,5])
y3 = np.array([10,20,30,40,50,60])
x4 = np.array([0,1,2,3,4,5])
y4 = np.array([200,350,250,550,450,150])

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title("Plot 1")

plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.title("Plot 2")

plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.title("Plot 3")

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title("Plot 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Question 4
#
# A bar plot is a graphical representation of data where rectangular bars are used to represent the quantities of different categories or groups.
#
# Uses:
# 1. Bar plots are particularly useful when you have categorical data, and you want to show the distribution or comparison of values across different categories.
# 2. Bar plots are straightforward and easy to interpret, making them a popular choice for data visualization.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple","Microsoft","Google","AMD"])
profit = np.array([3000,8000,1000,10000])

plt.bar(company,profit)
plt.show()
print('\n')
plt.barh(company,profit)
plt.show()

# %% [markdown]
# ## Question 5
#
# A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset. It provides a summary of key statistical measures, such as the median, quartiles, and potential outliers.
#
# Uses:
# 1. Box plots provide a clear and concise way to visualize the distribution of data, highlighting key summary statistics.
# 2. Box plots make it easy to compare the central tendency and spread of multiple datasets.
# 3. Box plots help in identifying potential outliers in a dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100,10,200)
box2 = np.random.normal(90,20,200)

plt.boxplot([box1,box2],labels=["Box 1","Box 2"])
plt.title("Comparison of Box1 and Box2")
plt.show()
